# %% [markdown]
# <a href="https://www.kaggle.com/code/dascient/osint-igf?scriptVersionId=193418788" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

from IPython.display import clear_output
# !pip install beautifulsoup4
# !pip install google

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: google in /opt/conda/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from google) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->google) (2.5)

# %% [markdown]
# Use Guarding The West as a person, device, or item, letters, hashtags.
# Sift through transcriptions (CC).
# Use a person’s voice to find them using public or private surveillance devices.
#
# https://www.kaggle.com/code/dascient/guarding-the-west
#
# Wifi signals can also provide environment vibrations (think sonar) in order to map out the layout of a room or location.
# WiVi - https://people.csail.mit.edu/fadel/wivi/project.html
#
# USING EVERYTHING

# %%
from googlesearch import search

# seqarch engine
query = input("type your subject's information here")

print("\nRetrieving links pertinent to query...\n")
queries = []
for j in search(query, tld="co.in", num=50, stop=50, pause=2):
    queries.append(j)
    print(j)

# create "Links"
queries = pd.DataFrame(queries,columns=["Links"])
queries
# Out:
# Retrieving links pertinent to query...
#
# https://www.linkedin.com/in/marcos-celis-111b01179
# https://www.linkedin.com/posts/marcos-c-bb9a15255_state-farm-insurance-agent-marcos-celis-in-activity-7140385609440722944-LB6E
# https://www.facebook.com/anthony.celisreinaga.5/
# https://m.facebook.com/public/Marc-Celis/
# https://www.instagram.com/marcos_celis/?hl=en
# https://www.pinterest.com/pin/pin-von-anthony-marcos-auf-shoplook--37436240645383734/
# https://veripages.com/name/Marco/Celis/
# https://www.wichitafallstx.gov/DocumentCenter/View/19632
# https://www.transfermarkt.com/diego-celis/spielegegeneinander/spieler/288785/page/7
# https://www.instagram.com/desenchufadas.ok/p/C20tNl7sUlP/
# https://www.courts.ca.gov/opinions-slip.htm?Courts=R
# https://historicimages.com/products/sas03913
# https://veripages.com/name/Anthony/Celis/
# https://www.cochise.az.gov/DocumentCenter/View/10619/Inmate-List-PDF
# https://institut-curie.org/personne/anthony-simon
# https://www.usphonebook.com/marco-celis
# https://www.researchgate.net/profile/Patrick-Celis
# https://www.idcrawl.com/anthony-celis
# https://ratings.fide.com/profile/54737702
# https://rcan.org/wp-content/uploads/2023/10/Vol.-58-No.-11-June-10-Catholic-Advocate.pdf
# https://www.tiktok.com/@marco.celis48/video/7397471391584472326?lang=bn-IN
# https://unmask.com/Marco-Celis/
# https://bhs.beaumontusd.us/apps/staff/
# https://orangecountyda.org/reports/
# https://dl.acm.org/doi/10.1145/2818048.2835202
# https://www.tiktok.com/@marco.celis48/video/7397881136753511685
# https://www.utep.edu/engineering/ctis/directory/alumni.html
# https://www.canada411.ca/Celis-1
# https://www.vermontjudiciary.org/courts/court-calendars/atty_calnames.htm
# https://www.novasbe.unl.pt/en/faculty-research/knowledge-centers/open-user-innovation/publications
# https://ivclasers.com/sports/msoc/2023-24/roster
# https://www2.traviscountytx.gov/courts/files/uploads/crimsettingsbydefendant.pdf
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10801747/
# http://sac.edu/pages/staff-directory.aspx
# https://www.officialcatholicdirectory.com/assets/OCD18_PriestsIndex.pdf
# https://www.dbm.gov.ph/wp-content/uploads/AboutDBM/2024-Philippine-Government-Directory.pdf
# https://www.csus.edu/college/engineering-computer-science/about-the-college/deans-honors-list.html
# https://ideas.repec.org/s/bjz/ajisjr.html
# https://sc.judiciary.gov.ph/list-of-successful-examinees/
# https://www.sandiego.edu/directory?name_search=&name_search_option=Any&relevancy=contains&user_type=Employee&sort=&list_view_type=list-view&filter_type=findpeople&show_image=Yes&details_button=show-details-button&department_filter_type=0&row_limit=24&division_id=NaN&office_department_id=24&sub_department_id=NaN&sub_unit_id=NaN&group_id=&filter_action=clicks
# https://www.allaboutjazz.com/musicians/tomas-celis-sanchez/
# https://www.bexar.org/DocumentCenter/View/7281/Unclaimed-Property-Notice?bidId=
# https://highland.aps.edu/contact-us
# https://www.philhealth.gov.ph/partners/employers/NonRemitting_NonReportingEmployers_022016.pdf
# https://www.congreso.gob.gt/noticias_congreso/11270/2024/1
# https://web.co.benton.mn.us/LETG/
# https://crismat.cnrs.fr/publications/
# https://www.state.gov/wp-content/uploads/2020/05/Diplomatic-Book-Spring-2020.pdf
# https://photogenie.be/archive/
# https://pubs.aeaweb.org/doi/10.1257/jep.12.2.91
#                                                 Links
# 0   https://www.linkedin.com/in/marcos-celis-111b0...
# 1   https://www.linkedin.com/posts/marcos-c-bb9a15...
# 2    https://www.facebook.com/anthony.celisreinaga.5/
# 3           https://m.facebook.com/public/Marc-Celis/
# 4       https://www.instagram.com/marcos_celis/?hl=en
# 5   https://www.pinterest.com/pin/pin-von-anthony-...
# 6             https://veripages.com/name/Marco/Celis/
# 7   https://www.wichitafallstx.gov/DocumentCenter/...
# 8   https://www.transfermarkt.com/diego-celis/spie...
# 9   https://www.instagram.com/desenchufadas.ok/p/C...
# 10  https://www.courts.ca.gov/opinions-slip.htm?Co...
# 11       https://historicimages.com/products/sas03913
# 12          https://veripages.com/name/Anthony/Celis/
# 13  https://www.cochise.az.gov/DocumentCenter/View...
# 14  https://institut-curie.org/personne/anthony-simon
# 15            https://www.usphonebook.com/marco-celis
# 16  https://www.researchgate.net/profile/Patrick-C...
# 17              https://www.idcrawl.com/anthony-celis
# 18          https://ratings.fide.com/profile/54737702
# 19  https://rcan.org/wp-content/uploads/2023/10/Vo...
# 20  https://www.tiktok.com/@marco.celis48/video/73...
# 21                    https://unmask.com/Marco-Celis/
# 22             https://bhs.beaumontusd.us/apps/staff/
# 23                https://orangecountyda.org/reports/
# 24     https://dl.acm.org/doi/10.1145/2818048.2835202
# 25  https://www.tiktok.com/@marco.celis48/video/73...
# 26  https://www.utep.edu/engineering/ctis/director...
# 27                   https://www.canada411.ca/Celis-1
# 28  https://www.vermontjudiciary.org/courts/court-...
# 29  https://www.novasbe.unl.pt/en/faculty-research...
# 30   https://ivclasers.com/sports/msoc/2023-24/roster
# 31  https://www2.traviscountytx.gov/courts/files/u...
# 32  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 33          http://sac.edu/pages/staff-directory.aspx
# 34  https://www.officialcatholicdirectory.com/asse...
# 35  https://www.dbm.gov.ph/wp-content/uploads/Abou...
# 36  https://www.csus.edu/college/engineering-compu...
# 37          https://ideas.repec.org/s/bjz/ajisjr.html
# 38  https://sc.judiciary.gov.ph/list-of-successful...
# 39  https://www.sandiego.edu/directory?name_search...
# 40  https://www.allaboutjazz.com/musicians/tomas-c...
# 41  https://www.bexar.org/DocumentCenter/View/7281...
# 42                https://highland.aps.edu/contact-us
# 43  https://www.philhealth.gov.ph/partners/employe...
# 44  https://www.congreso.gob.gt/noticias_congreso/...
# 45                  https://web.co.benton.mn.us/LETG/
# 46              https://crismat.cnrs.fr/publications/
# 47  https://www.state.gov/wp-content/uploads/2020/...
# 48                     https://photogenie.be/archive/
# 49    https://pubs.aeaweb.org/doi/10.1257/jep.12.2.91
