# %% [markdown]
# <a href="https://www.kaggle.com/code/dascient/osint-igf?scriptVersionId=215626411" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Use Guarding The West as a person, device, or item, letters, hashtags.
# Sift through transcriptions (CC).
# Use a person’s voice to find them using public or private surveillance devices.
#
# https://www.kaggle.com/code/dascient/guarding-the-west
#
# Wifi signals can also provide environment vibrations (think sonar) in order to map out the layout of a room or location.
# WiVi - https://people.csail.mit.edu/fadel/wivi/project.html
#
# USING EVERYTHING

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

from IPython.display import clear_output
# !pip install beautifulsoup4
# !pip install google

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Collecting google
#   Downloading google-3.0.0-py2.py3-none-any.whl.metadata (627 bytes)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from google) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->google) (2.5)
# Downloading google-3.0.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: google
# Successfully installed google-3.0.0

# %%
from googlesearch import search

# seqarch engine
query = "nalresearch NwsWebService" #input("type your subject's information here")

print("\nRetrieving links pertinent to query...\n")
queries = []
for j in search(query, tld="co.in", num=50, stop=50, pause=2):
    queries.append(j)
    print(j)

# create "Links"
queries = pd.DataFrame(queries,columns=["Links"])
queries
# Out:
# Retrieving links pertinent to query...
#
# https://www.nalresearch.com/
# https://www.nalresearch.com/shop/
# https://www.nalresearch.com/contact/
# https://www.nalresearch.com/about/
# https://www.nalresearch.com/services/
# https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=635365584db46afd909e50d1faec43b0a8a90d9b
# https://docs.oracle.com/en/cloud/saas/transportation/24c/otmol/properties/glog/integration.property.htm
# https://taoxie.cs.illinois.edu/publications/icws07.pdf
# https://richardberrocal.com/IDAT/DAE_SOA/bibliografia_basica/Libro_SOA_using_JavaWebServices_Hansen2007-05-19.pdf
# https://www.gsma.com/newsroom/wp-content/uploads//RCC.07-v12.0-2.pdf
# https://www.researchgate.net/publication/339709869_Intelligent_Framework_for_Web-Service_Testing/download
# https://www.scitepress.org/publishedPapers/2019/79792/pdf/index.html
# https://www.yumpu.com/en/document/view/44154312/nal-research-corporation
# https://lirias.kuleuven.be/retrieve/676385
# https://ec.europa.eu/research/participants/documents/downloadPublic?documentIds=080166e5bca75baf&appId=PPGMS
# https://au.linkedin.com/company/jws-research
# https://bibliotekanauki.pl/articles/384067.pdf
# https://www.jwsresearch.com/wp-content/uploads/2022/08/JWS-Research-True-Issues-28-August-2022-Indigenous-Voice-to-Parliament.pdf
# https://www.researchgate.net/publication/4186639_Using_Web_services_and_data_mediationstorage_services_to_enable_command_and_control_to_simulation_interoperability
# https://www.redbooks.ibm.com/redpapers/pdfs/redp4884.pdf
# https://doras.dcu.ie/16811/2/PhD_Thesis_Jan_28_2012-Kosala.pdf
# https://pure.uva.nl/ws/files/4213210/42730_Jong_Hayco_de.pdf
# https://link.springer.com/chapter/10.1007/11762256_43
# https://penni.wu.ac.at/papers/JWS%202021%20Intelligent%20Software%20Web%20Agents%20A%20Gap%20Analysis.pdf
# https://papers.ssrn.com/sol3/Delivery.cfm/jws-4_3_4.pdf?abstractid=3199337&mirid=1
# https://stackoverflow.com/questions/52857820/cxf-codegen-maven-plugin-doesnt-work-openjdk-11
# https://eprints.soton.ac.uk/258692/1/jws-2003a.pdf
# https://pure.tudelft.nl/ws/files/40152770/dissertation_repository.pdf
# https://research.utwente.nl/files/325395475/Eighth_Real-Time_Linux_Workshop.pdf
# https://trasparenza.fbk.eu/content/download/8465/164307/file/implementation_plan_2012.pdf
# http://oaei.ontologymatching.org/doc/Proceedings-OM-2006.pdf
# https://www.semantic-web-journal.net/system/files/swj2058.pdf
# https://www.jwsresearch.com/
# https://www.slideshare.net/slideshow/call-for-research-articles-international-journal-on-web-service-computing-ijwsc-ac81/274111811
