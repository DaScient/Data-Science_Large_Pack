# %% [markdown]
# <a href="https://www.kaggle.com/code/dascient/osint-igf?scriptVersionId=189591741" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

from IPython.display import clear_output
# !pip install beautifulsoup4
# !pip install google

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Use Guarding The West as a person, device, or item, letters, hashtags.
# Sift through transcriptions (CC).
# Use a person’s voice to find them using public or private surveillance devices.
#
# https://www.kaggle.com/code/dascient/guarding-the-west
#
# Wifi signals can also provide environment vibrations (think sonar) in order to map out the layout of a room or location.
# WiVi - https://people.csail.mit.edu/fadel/wivi/project.html

# %%
from googlesearch import search

# seqarch engine
query = "don darrel tadaya" #input("type your search here")

print("\nRetrieving links pertinent to query...\n")
queries = []
for j in search(query, tld="co.in", num=50, stop=50, pause=2):
    queries.append(j)
    print(j)

# create "Links"
queries = pd.DataFrame(queries,columns=["Links"])
queries
# Out:
# Retrieving links pertinent to query...
#
# https://www.usphonebook.com/don-darrel-tadaya/UkDN5MDO1ATN0IjM0kTO1gzR
# https://recorder.maricopa.gov/GisOrdinances/FireDistricts/TonopahValleyFireDistrict/TonopahFireAnnexation_12-13-464.pdf
# https://www.fastpeoplesearch.com/301-675-0611
# https://www.instagram.com/iamdondarrell/
# https://www.instantcheckmate.com/people/nikko-tadaya/
# https://www.bizapedia.com/az/dascient-llc.html
# https://www.qls.com.au/getattachment/1362cb96-369e-48dc-b243-0c9476f27f7c/register-of-solicitors-20240503-m-r.pdf
# https://www.facebook.com/kkbpaniquiofficial/photos/a.771913316186079/4878864392157597/?type=3&locale=tl_PH
# https://www.searchpeoplefree.com/address/ca/long-beach/e-poinsettia-st/2257
# https://www.facebook.com/ILoveTarlacFoodsandVlogs/videos/fab-caff%C3%A9-paniqui-tarlac-give-awayto-all-the-participants-kindly-check-your-name/3605837649502603/
# https://www.laguardia.edu/deans-list/
# https://stories.foundever.com/the-stories/
# ...

# %%
# https://search15.lycos.com/web/?q=don+tadaya
# https://web.archive.org/web/20240522112243/https://dascientcapital.us/
